# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"  # Force CPU

import sys
sys.path.append(os.path.abspath(".."))  

import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import DQN
from stable_baselines3.common.monitor import Monitor

# Project Imports
from environment.env import Simulatio4RecSys
from environment.items_selection import GreedySelector
from environment.reward_perturbator import NoPerturbator
from environment.reward_shaping import IdentityRewardShaping
from environment.citations.citation_loader import CitationsLoader
from environment.citations.citations_retrieval import CitationsRetrieval
from environment.users.citation_users_loader import CitationUsersLoader
# from environment.LLM.small_hf_llm import SmallHuggingfaceLLM
from environment.flat_obs_wrapper import FlatObsWrapper
# from environment.LLM.rater import CitationLLMRater

# %%
# # environment/LLM/rater.py

# from environment.LLM.llm import LLM
# from environment.LLM.rater import LLMRater

# class CitationLLMRater(LLMRater):
#     def __init__(self, llm, current_items_features_list=[], previous_items_features_list=[], llm_render=False, llm_query_explanation=False):
#         super().__init__(llm, current_items_features_list, previous_items_features_list, llm_render, llm_query_explanation)
#         self.request_scale = "0-9"
#         self.system_prompt = (
#     "You are simulating a user's preferences for scientific papers.\n"
#     "Consider the following factors when rating a paper from 0 (not interested) to 9 (extremely interested):\n"
#     "- How closely the paper's TOPICS match the user's interests.\n"
#     "- Whether the user prefers NOVELTY (more recent papers).\n"
#     "- Whether the user prefers REPUTABILITY (highly cited papers).\n"
#     "\n"
#     "If a paper matches the user's topics AND fits their novelty/reputability preferences, rate it HIGH (8-9).\n"
#     "If it poorly matches in topics or is too old/too low-cited based on user's preferences, rate it LOW (0-3).\n"
#     "\n"
#     "ONLY output a single number between 0 and 9."
# )


#     def _get_few_shot_prompts(self):
#         # (Optional for smarter few-shot prompts later)
#         return []

#     def _get_prompt(self, user, item, num_interacted, interactions, retrieved_items):
#         user_info = (
#             f"{user.description}"
#             # f"Novelty Preference: {getattr(user, 'novelty_preference', 'Unknown')}\n"
#             # f"Reputability Bias: {getattr(user, 'reputability_bias', 'Unknown')}\n"
#         )
#         paper_info = (
#             f"Paper Title: {item.title}\n"
#             f"Topics: {', '.join(item.topics)}\n"
#             f"Publication Year: {item.year}\n"
#             f"Citations Count: {item.cited_by_count}\n"
#         )
#         print(f"User Info: {user_info}")
#         print(f"Paper Info: {paper_info}")
#         question = "Question: How much would the user like this paper? (ONLY output a number between 0 and 9.)"
#         return [{"role": "user", "content": f"{self.system_prompt}\n\n{user_info}\n\n{paper_info}\n\n{question}"}]

#     def adjust_rating_in(self, rating):
#         return rating

#     def adjust_rating_out(self, rating):
#         return rating

#     def adjust_text_in(self, text):
#         return text

# %%
# environment/LLM/smart_citation_llm_rater.py

from environment.LLM.rater import LLMRater

class SmartCitationLLMRater(LLMRater):
    def __init__(self, llm, current_items_features_list=[], previous_items_features_list=[], llm_render=False, llm_query_explanation=False):
        super().__init__(llm, current_items_features_list, previous_items_features_list, llm_render, llm_query_explanation)
        self.request_scale = "0-9"
        self.system_prompt = (
            '''You are simulating a user rating scientific papers.
                When rating, you MUST consider the following:

                - Topic Matching: Rate higher if paper topics match user's interests.
                - Novelty Preference: The user has a novelty preference score from 0 (does not care about recency) to 1 (cares strongly about recency). 
                You should reward papers with a Normalized Year closer to 1 based on the user's novelty preference.
                - Reputability Bias: The user has a reputability bias score from 0 (does not care about citations) to 1 (cares strongly about highly cited papers).
                You should reward papers with a Normalized Citations (Reputability) closer to 1 based on the user's reputability bias.
                
                You must **combine these factors** logically to decide if the user would rate the paper highly or not.
                ONLY output a single rating from 0 (not interested) to 9 (extremely interested).
'''
        )

        # Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
    def _get_few_shot_prompts(self):
        # (Optional for smarter few-shot prompts later)
        return []
    def _get_prompt(self, user, item, num_interacted, interactions, retrieved_items):
        user_info = (
            f"User Profile:\n"
            f" {user.description}"
            # f"- Novelty Preference (0-1): {user.novelty_preference:.2f}\n"
            # f"- Reputability Bias (0-1): {user.reputability_bias:.2f}\n"
        )

        paper_info = (
            f"Paper Details:\n"
            f"- Title: {item.title}\n"
            f"- Topics: {', '.join(item.topics)}\n"
            f"- Normalized Year (0-1): {item.norm_year:.2f}\n"
            f"- Normalized Citations (Reputability) (0-1): {item.norm_cite:.2f}\n"
        )
        print(f"User Info: {user_info}")
        print(f"Paper Info: {paper_info}")
        question = "Question:\nHow much would the user like this paper? (ONLY output a number from 0 to 9)"

        full_prompt = f"{self.system_prompt}\n\n{user_info}\n\n{paper_info}\n\n{question}"

        return [{"role": "user", "content": full_prompt}]

    def adjust_rating_in(self, rating):
        return rating

    def adjust_rating_out(self, rating):
        return rating

    def adjust_text_in(self, text):
        return text

# %%
# environment/LLM/small_hf_llm.py

from environment.LLM.llm import LLM
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

class SmallHuggingfaceLLM(LLM):
    def __init__(self, model_name="google/flan-t5-large", device="cpu"):
        super().__init__(model_name)
        self.device = device
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModelForSeq2SeqLM.from_pretrained(model_name).to(device)
        self.model.eval()

    def _generate(self, prompt):
        inputs = self.tokenizer(prompt, return_tensors="pt").to(self.device)
        outputs = self.model.generate(
            **inputs,
            max_new_tokens=10,
            pad_token_id=self.tokenizer.eos_token_id
        )
        text = self.tokenizer.decode(outputs[0], skip_special_tokens=True)
        return text

    def request_rating_0_9(self, system_prompt, dialog):
        prompt = self._dialog_to_text(dialog)
        response = self._generate(prompt)
        return prompt, self._extract_number(response, 0, 9)

    def request_rating_1_10(self, system_prompt, dialog):
        prompt = self._dialog_to_text(dialog)
        response = self._generate(prompt)
        return prompt, self._extract_number(response, 1, 10)

    def request_rating_text(self, system_prompt, dialog):
        prompt = self._dialog_to_text(dialog)
        response = self._generate(prompt)
        return prompt, response

    def request_explanation(self, system_prompt, dialog):
        prompt = self._dialog_to_text(dialog)
        response = self._generate(prompt)
        return prompt, response

    def _dialog_to_text(self, dialog):
        return "\n".join([f"{d['role'].capitalize()}: {d['content']}" for d in dialog])

    def _extract_number(self, text, min_val, max_val):
        import re
        numbers = re.findall(r'\d+', text)
        for num in numbers:
            n = int(num)
            if min_val <= n <= max_val:
                return str(n)
        return str((min_val + max_val) // 2)  # fallback: middle value

# %%
llm = SmallHuggingfaceLLM(model_name="google/flan-t5-small", device="cpu")
rater = SmartCitationLLMRater(llm)

# %%
import random
import pandas as pd
from environment.users.user import User
from environment.citations.citation import Citation
# --------------------------------------------
# Create the user
# --------------------------------------------
example_user = users_loader.get_users()[0]
example_user.novelty_preference = 0.74
example_user.reputability_bias = 0.47

# --------------------------------------------
# Create two synthetic papers
# --------------------------------------------

# ✅ Relevant paper
relevant_paper = Citation(
    id=1000,
    title="Advances in Web Visibility and Informetrics Techniques",
    year=2022,
    topics=["Web visibility and informetrics", "Scientometrics"],
    topic_scores=[0.98, 0.95],
    cited_by_count=2500,
    norm_cite=0.9,
    norm_year=0.98
)

# ❌ Irrelevant paper
irrelevant_paper = Citation(
    id=1001,
    title="Crop Rotation Strategies in Agricultural Sciences",
    year=2010,
    topics=["Agricultural Sciences", "Crop Management"],
    topic_scores=[0.7, 0.65],
    cited_by_count=120,
    norm_cite=0.2,
    norm_year=0.6
)

rating_relevant, _, _ = rater.query(example_user, relevant_paper, 0, [], [])
rating_irrelevant, _, _ = rater.query(example_user, irrelevant_paper, 0, [], [])

print(f"\n✅ Predicted Rating for Relevant Paper: {rating_relevant}")
print(f"❌ Predicted Rating for Irrelevant Paper: {rating_irrelevant}")
# Out:
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Advances in Web Visibility and Informetrics Techniques
# - Topics: Web visibility and informetrics, Scientometrics
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.90
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Crop Rotation Strategies in Agricultural Sciences
# - Topics: Agricultural Sciences, Crop Management
# - Normalized Year (0-1): 0.60
# - Normalized Citations (Reputability) (0-1): 0.20
#
#
# ✅ Predicted Rating for Relevant Paper: 4.0
# ❌ Predicted Rating for Irrelevant Paper: 0.0

# %%
import random
import pandas as pd
from environment.users.user import User
from environment.citations.citation import Citation


# ---------------
# Load data
# ---------------

# Load papers
papers_df = pd.read_csv(csv_path)

# Load users (list of dicts)
import json
with open(users_path, "r") as f:
    users_data = json.load(f)


# ---------------
# Select 1 User
# ---------------

user_info = users_data[0]
user = example_user
print(f"🧑‍💼 User Description: {user.description}")
print()

# ---------------
# Select 30 Random Papers
# ---------------

sample_papers = papers_df.sample(30, random_state=42)

# ---------------
# Rate Papers
# ---------------

results = []

for idx, row in sample_papers.iterrows():
    citation = Citation(
        id=idx,
        title=row["title"],
        year=row["publication_year"],
        topics=eval(row["topics.display_name"]),
        topic_scores=eval(row["topics.score"]),
        cited_by_count=row["cited_by_count"],
        norm_cite=row["cited_by_count_norm"],
        norm_year=row["publication_year_norm"]
    )

    # Query LLM
    rating, explanation, _ = rater.query(
        user=user,
        item=citation,
        num_interacted=0,
        interactions=[],
        retrieved_items=[]
    )

    results.append({
        "Paper Title": citation.title,
        "Publication Year": citation.year,
        "Cited By Count": citation.cited_by_count,
        "Topics": ", ".join(citation.topics),
        "Normalized Cite": citation.norm_cite,
        "Normalized Year": citation.norm_year,
        "LLM Rating (0-9)": rating
    })

# ---------------
# View Results
# ---------------

results_df = pd.DataFrame(results)
display(results_df)
# Out:
# 🧑‍💼 User Description: Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Correlational analysis of topic specificity and citations count of publication venues
# - Topics: scientometrics and bibliometrics research, Complex Network Analysis Techniques, Species Distribution and Climate Change
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.30
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Infrastructures de science ouverte
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: How can we assess scientific quality? Citation index only for original research and/or for authorship in the guidelines?
# - Topics: scientometrics and bibliometrics research, Meta-analysis and systematic reviews, Academic Writing and Publishing
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.15
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: The Torsion Balance Company
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.95
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Practice and Challenge of International Peer Review: A Case Study of Research Evaluation of CAS Centers for Excellence
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.09
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: How an editorial in a scientific journal can help changing the prevailing practices in a scientific stream?
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: The BiPublishers ranking: Main results and methodological problems when constructing rankings of academic publishers
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: British Association for the Advancement of Science
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.92
# - Normalized Citations (Reputability) (0-1): 0.14
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: “The chemistry and technology of the diazo‐compounds.”. By J. C. Cain. Second edition. Pp. xii. + 199. (London: Edward Arnold. 1920.) Price 12s. 6d. net
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.87
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Scientometrics: Methodology and Tools
# - Topics: scientometrics and bibliometrics research, Research Data Management Practices, Academic Publishing and Open Access
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.11
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Zinner's Comet 1913
# - Topics: scientometrics and bibliometrics research, History and Developments in Astronomy
# - Normalized Year (0-1): 0.86
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Russian Science Citation Index on the WoS platform: a critical assessment
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.29
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Last and corresponding authorship practices in ecology
# - Topics: scientometrics and bibliometrics research, Meta-analysis and systematic reviews
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.41
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Artificial intelligence in chemistry
# - Topics: scientometrics and bibliometrics research, Biomedical Text Mining and Ontologies, Machine Learning in Materials Science
# - Normalized Year (0-1): 0.96
# - Normalized Citations (Reputability) (0-1): 0.34
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Scientific World and its transmission of physics and chemistry
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Academic research productivity: Reply, still further results
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.97
# - Normalized Citations (Reputability) (0-1): 0.29
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Open Access: Ideas and Suggestions for Dental Stakeholders
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Research Data Management Practices
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: On the comparison of extensive and intensive measures of the efficiency of scientific groups
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: 10 Questions: Approaches to Research Funding
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: LESS "OUCH" FOR FOOTBALL PLAYERS
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.92
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: On an approach to boosting a journal’s citation potential
# - Topics: scientometrics and bibliometrics research, Research Data Management Practices, Academic Publishing and Open Access
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Reverse the Curse of the Top-5
# - Topics: scientometrics and bibliometrics research, Meta-analysis and systematic reviews, Research, Science, and Academia
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.34
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: What Do Chemists Cite? A 5-year Analysis of References Cited in American Chemical Society Journal Articles
# - Topics: scientometrics and bibliometrics research, Academic Writing and Publishing, History and advancements in chemistry
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.25
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Using network analysis to compare bibliographic database journal coverage
# - Topics: scientometrics and bibliometrics research, Complex Network Analysis Techniques, Advanced Text Analysis Techniques
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.09
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Trends and topics in eye disease research in PubMed from 2010 to 2014
# - Topics: scientometrics and bibliometrics research, Retinal Imaging and Analysis
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.36
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: The impact of open access on citations, Pageviews, and downloads: a scientometric analysis in <i>Postgraduate Medical Journal</i>
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Meta-analysis and systematic reviews
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Open Access and the Humanities: The Case of Classics Journals
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.24
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Open Access in Scholarly Publishing: Where Does the <i>Journal</i><i>of Midwifery &amp; Women's Health</i> Fit In?
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Migrant scientists and international networks
# - Topics: scientometrics and bibliometrics research, Innovation Policy and R&D, Economic Growth and Development
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: A new journal citation impact measure that compensates for disparities in citation potential among research areas
# - Topics: scientometrics and bibliometrics research, Research Data Management Practices
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.17
#                                           Paper Title  Publication Year  \
# 0   Correlational analysis of topic specificity an...              2018
# 1                  Infrastructures de science ouverte              2024
# 2   How can we assess scientific quality? Citation...              2014
# 3                         The Torsion Balance Company              1973
# 4   Practice and Challenge of International Peer R...              2019
# 5   How an editorial in a scientific journal can h...              2023
# 6   The BiPublishers ranking: Main results and met...              2015
# 7   British Association for the Advancement of Sci...              1955
# 8   “The chemistry and technology of the diazo‐com...              1920
# 9               Scientometrics: Methodology and Tools              2016
# 10                                Zinner's Comet 1913              1913
# 11  Russian Science Citation Index on the WoS plat...              2019
# 12  Last and corresponding authorship practices in...              2017
# 13               Artificial intelligence in chemistry              1988
# 14  Scientific World and its transmission of physi...              2010
# 15  Academic research productivity: Reply, still f...              1992
# 16  Open Access: Ideas and Suggestions for Dental ...              2023
# 17  On the comparison of extensive and intensive m...              2014
# 18       10 Questions: Approaches to Research Funding              2016
# 19                   LESS "OUCH" FOR FOOTBALL PLAYERS              1952
# 20  On an approach to boosting a journal’s citatio...              2019
# 21                     Reverse the Curse of the Top-5              2019
# 22  What Do Chemists Cite? A 5-year Analysis of Re...              2018
# 23  Using network analysis to compare bibliographi...              2020
# 24  Trends and topics in eye disease research in P...              2016
# 25  The impact of open access on citations, Pagevi...              2024
# 26  Open Access and the Humanities: The Case of Cl...              2017
# 27  Open Access in Scholarly Publishing: Where Doe...              2024
# 28      Migrant scientists and international networks              2014
# 29  A new journal citation impact measure that com...              2010
#
#     Cited By Count                                             Topics  \
# 0               20  scientometrics and bibliometrics research, Com...
# 1                0          scientometrics and bibliometrics research
# 2                5  scientometrics and bibliometrics research, Met...
# 3                1          scientometrics and bibliometrics research
# 4                2          scientometrics and bibliometrics research
# 5                0          scientometrics and bibliometrics research
# 6                0          scientometrics and bibliometrics research
# 7                4          scientometrics and bibliometrics research
# 8                0          scientometrics and bibliometrics research
# 9                3  scientometrics and bibliometrics research, Res...
# 10               0  scientometrics and bibliometrics research, His...
# 11              19  scientometrics and bibliometrics research, Aca...
# 12              53  scientometrics and bibliometrics research, Met...
# 13              29  scientometrics and bibliometrics research, Bio...
# 14               0          scientometrics and bibliometrics research
# 15              19          scientometrics and bibliometrics research
# 16               0  scientometrics and bibliometrics research, Aca...
# 17               1          scientometrics and bibliometrics research
# 18               0          scientometrics and bibliometrics research
# 19               0          scientometrics and bibliometrics research
# 20               1  scientometrics and bibliometrics research, Res...
# 21              30  scientometrics and bibliometrics research, Met...
# 22              13  scientometrics and bibliometrics research, Aca...
# 23               2  scientometrics and bibliometrics research, Com...
# 24              34  scientometrics and bibliometrics research, Ret...
# 25               0  scientometrics and bibliometrics research, Aca...
# 26              12  scientometrics and bibliometrics research, Aca...
# 27               1  scientometrics and bibliometrics research, Aca...
# 28             152  scientometrics and bibliometrics research, Inn...
# 29               6  scientometrics and bibliometrics research, Res...
#
#     Normalized Cite  Normalized Year  LLM Rating (0-9)
# 0          0.295771         0.993555               0.0
# 1          0.000000         0.999091               0.0
# 2          0.154523         0.989781               0.0
# 3          0.050013         0.946613               0.0
# 4          0.085497         0.994488               0.0
# 5          0.000000         0.998179               0.0
# 6          0.000000         0.990731               0.0
# 7          0.135510         0.924448               0.0
# 8          0.000000         0.873243               0.0
# 9          0.113021         0.991677               0.0
# 10         0.000000         0.861316               0.0
# 11         0.290033         0.994488               4.0
# 12         0.408792         0.992618               0.0
# 13         0.338072         0.963451               0.0
# 14         0.000000         0.985939               0.0
# 15         0.290033         0.967723               0.0
# 16         0.000000         0.998179               0.0
# 17         0.050013         0.989781               0.0
# 18         0.000000         0.991677               0.0
# 19         0.000000         0.920516               0.0
# 20         0.050013         0.994488               0.0
# 21         0.341988         0.994488               0.0
# 22         0.248530         0.993555               0.0
# 23         0.085497         0.995417               0.0
# 24         0.356516         0.991677               0.0
# 25         0.000000         0.999091               0.0
# 26         0.240020         0.992618               0.0
# 27         0.050013         0.999091               0.0
# 28         0.535792         0.989781               0.0
# 29         0.170994         0.985939               0.0

# %%
# results_df.to_csv("llm_ratings.csv", index=False)

# %%
user.description
# Out:
# 'Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47'

# %%
# Load 1 example user
example_user = users_loader.get_users()[0]

# Print its fields
print("\n🧑‍💼 Example User:")
print(f"Name: {example_user.name}")
print(f"Gender: {example_user.gender}")
print(f"Age: {example_user.age}")
print(f"Description: {example_user.description}")

# (If you manually added novelty_preference and reputability_bias to user object, print them too)
if hasattr(example_user, "novelty_preference"):
    print(f"Novelty Preference: {example_user.novelty_preference}")
if hasattr(example_user, "reputability_bias"):
    print(f"Reputability Bias: {example_user.reputability_bias}")
# Out:
# 🧑‍💼 Example User:
# Name: CitationUser0
# Gender: M
# Age: 30
# Description: Interested in: Web visibility and informetrics. Prefers novelty: 0.74, reputability bias: 0.47
# Novelty Preference: 0.74
# Reputability Bias: 0.47

# %%
# Load 1 example paper
example_paper = items_loader.load_items_from_ids([10])[0]

# Print its fields
print("📚 Example Paper:")
print(f"Title: {example_paper.title}")
print(f"Year: {example_paper.year}")
print(f"Topics: {example_paper.topics}")
print(f"Topic Scores: {example_paper.topic_scores}")
print(f"Cited By Count: {example_paper.cited_by_count}")
print(f"Normalized Citations: {example_paper.norm_cite:.2f}")
print(f"Normalized Year: {example_paper.norm_year:.2f}")
# Out:
# 📚 Example Paper:
# Title: The bibliometric analysis of scholarly production: How great is the impact?
# Year: 2015
# Topics: ['scientometrics and bibliometrics research', 'Web visibility and informetrics']
# Topic Scores: [0.9975, 0.9853]
# Cited By Count: 2216
# Normalized Citations: 0.86
# Normalized Year: 0.99

# %%
csv_path = "../environment/citations/datasets/cleaned-scientometrics-and-bibliometrics-research.csv"
users_path = "../environment/users/datasets/citation_users.json"

items_loader = CitationsLoader(csv_path)
users_loader = CitationUsersLoader(users_path)

# %%
# # --- Small Huggingface LLM ---
# llm = SmallHuggingfaceLLM(model_name="sshleifer/tiny-gpt2", device="cpu")
# llm_rater = CitationLLMRater(llm=llm, current_items_features_list=[], previous_items_features_list=[])


llm = SmallHuggingfaceLLM(model_name="google/flan-t5-small", device="cpu")
rater = SmartCitationLLMRater(llm)

# --- Environment ---
raw_env = Simulatio4RecSys(
    render_mode="human",
    items_loader=items_loader,
    users_loader=users_loader,
    items_selector=GreedySelector(),
    reward_perturbator=NoPerturbator(),
    items_retrieval=CitationsRetrieval(),
    reward_shaping=IdentityRewardShaping(),
    llm_rater=rater
)

env = FlatObsWrapper(raw_env)
env = Monitor(env)

# %%
model = DQN("MultiInputPolicy", env, verbose=1, device="cpu")
model.learn(total_timesteps=10000)
model.save("models/dqn_citation_recommender")

# ===============================
# Plot Rewards
# ===============================

rewards = env.get_episode_rewards()
plt.figure(figsize=(12, 5))
plt.plot(rewards)
plt.title("DQN - Reward per Episode")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.grid(True)
plt.show()
# Out:
# Using cpu device
# Wrapping the env in a DummyVecEnv.
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: If We Want a Lottery in Research Funding, Let's Split Our Bets, and Save Something for Later …
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Ranking Predatory Journals; Solve the Problem Instead of Removing It!
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.44
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Workshop on Research Assessment Practices in Indian Funding Agencies
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Research Data Management Practices
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.09
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: A persistent lack of International representation on editorial boards in environmental biology
# - Topics: scientometrics and bibliometrics research, Climate Change Communication and Perception, Microbial Community Ecology and Physiology
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: From the Archive: “Web of Science (2004 Version) and Scopus”
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: An analysis of personal journal subscriptions of university faculty. Part I. science
# - Topics: scientometrics and bibliometrics research, Academic Writing and Publishing, Publishing and Scholarly Communication
# - Normalized Year (0-1): 0.97
# - Normalized Citations (Reputability) (0-1): 0.09
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Book Review: Cribb, J., &amp; Sari, T. (2010). Open Science: Sharing Knowledge in the Global Century. Collingwood, Victoria, Australia: CSIRO. pp. 221. ISBN 978-0643097636
# - Topics: scientometrics and bibliometrics research, Research Data Management Practices
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Taux des publications des chirurgiens orthopédistes-traumatologues français dans les revues prédatrices : note de suivi
# - Topics: scientometrics and bibliometrics research, Meta-analysis and systematic reviews, Healthcare Systems and Practices
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Research Guides: EndNote Web: Home
# - Topics: scientometrics and bibliometrics research, Academic Writing and Publishing
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: El índice de impacto de las publicaciones científicas
# - Topics: scientometrics and bibliometrics research, Psychology Research and Bibliometrics, Academic Writing and Publishing
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Upcoming Meetings and World Congress Site
# - Topics: scientometrics and bibliometrics research, Renal and Vascular Pathologies
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: The 'publish or perish'-pressure - beneficial to academic research?
# - Topics: scientometrics and bibliometrics research, Science and Climate Studies
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Markets for Scientific Attribution
# - Topics: scientometrics and bibliometrics research, Private Equity and Venture Capital, Pharmaceutical industry and healthcare
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.14
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Issue Publication Information
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: PIONEERING AT BELL TELEPHONE LABORATORIES
# - Topics: scientometrics and bibliometrics research, Various Chemistry Research Topics, Twentieth Century Scientific Developments
# - Normalized Year (0-1): 0.93
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: The contribution of countries and world regions in productivity of oncological publication
# - Topics: scientometrics and bibliometrics research, Health Systems, Economic Evaluations, Quality of Life, Health and Medical Research Impacts
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.32
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: VICTOR Chemicals
# - Topics: scientometrics and bibliometrics research, History and advancements in chemistry, Chemistry and Chemical Engineering
# - Normalized Year (0-1): 0.91
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Scientific Research and Development in Great Britain
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.91
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Issue Publication Information
# - Topics: scientometrics and bibliometrics research, History and advancements in chemistry
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Ranking academic departments: Empirical findings and a theoretical perspective
# - Topics: scientometrics and bibliometrics research, Higher Education Governance and Development
# - Normalized Year (0-1): 0.96
# - Normalized Citations (Reputability) (0-1): 0.35
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: How to Write a Grant Proposal: An Introduction to Grants and Programs at the Wenner-Gren Foundation and the National Science Foundation
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Probability and expected frequency of breakthroughs: basis and use of a robust method of research assessment
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.26
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: Processing Academic Article Information for Predicting the Quality of Academic Journals
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Publishing and Open Access, Complex Network Analysis Techniques, Science and Science Education. Prefers novelty: 0.29, reputability bias: 0.33
# Paper Info: Paper Details:
# - Title: La bibliometría se refiere a la cuantificación y evaluación de la producción científica de un país, una institución, o de un autor. Son pocos los estudios bibliométricos de los investigadores paraguayos. El objetivo de este trabajo fue estudiar la producc
# - Topics: scientometrics and bibliometrics research, Psychology Research and Bibliometrics, Scientific Research and Technology
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: The structure of scientific and engineering papers: a historical perspective
# - Topics: scientometrics and bibliometrics research, Academic Writing and Publishing
# - Normalized Year (0-1): 0.96
# - Normalized Citations (Reputability) (0-1): 0.38
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Distribution of Academic Research Funds: Case of Japanese National Research Grant
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.21
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Decision letter for "We need to rethink the way we identify diamond open access journals in quantitative science studies"
# - Topics: scientometrics and bibliometrics research, Data Analysis with R
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Chapter 9. Research excellence in Portugal and its funding
# - Topics: scientometrics and bibliometrics research, Innovation Policy and R&D
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: THE WELCH SCIENTIFIC CO.
# - Topics: scientometrics and bibliometrics research, Academic Writing and Publishing
# - Normalized Year (0-1): 0.93
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: First Source for Laboratory Reagents
# - Topics: scientometrics and bibliometrics research, History and advancements in chemistry
# - Normalized Year (0-1): 0.91
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Which H-Index? An Investigation on the Relation Between Google Scholar and Web of Science Values
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Mendeley reader counts for US computer science conference papers and journal articles
# - Topics: scientometrics and bibliometrics research, Online Learning and Analytics, Machine Learning in Materials Science
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.30
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Words and co-words as indicators of intellectual organization
# - Topics: scientometrics and bibliometrics research, Advanced Text Analysis Techniques, Biomedical Text Mining and Ontologies
# - Normalized Year (0-1): 0.96
# - Normalized Citations (Reputability) (0-1): 0.58
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Nontraditional Approaches to Assessing Journal Importance: Case Study of Russian Journals on Earth Sciences
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.19
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: RESEARCH FRONTS 2014:100 TOP RANKED SPECIALTIES IN THE SCIENCES AND SOCIAL SCIENCES
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Research Data Management Practices
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.15
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: The Promethean fire
# - Topics: scientometrics and bibliometrics research, Meta-analysis and systematic reviews, Musculoskeletal Disorders and Rehabilitation
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.15
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: A plea for peer review
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.96
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Inventarisatie van peer review applicaties. Uitgevoerd in het kader van het SURF-project Peer Review Online - Opschalen en Faciliteren
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Review of: "Publish or perish: time for a rethink?"
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Patterns of co-authorship and research collaboration in Malaysia
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Academic Writing and Publishing
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.30
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: University of California Research Seminar Network: A Prospectus
# - Topics: scientometrics and bibliometrics research, Research Data Management Practices, Species Distribution and Climate Change
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: An Overview on Evaluating and Predicting Scholarly Article Impact
# - Topics: scientometrics and bibliometrics research, Complex Network Analysis Techniques
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.42
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: CV Polymerase: A Publication Primer for Young Pathology Faculty Members
# - Topics: scientometrics and bibliometrics research, Genetics, Bioinformatics, and Biomedical Research, Academic Writing and Publishing
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: fictionist, n.
# - Topics: scientometrics and bibliometrics research, Philosophy and History of Science, Computational and Text Analysis Methods
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Editorial: Quality and quantity in research assessment: Examining the merits of metrics
# - Topics: scientometrics and bibliometrics research, Meta-analysis and systematic reviews
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.14
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: dataIs the System of Scientific Publications on the Eve of a Revolution? And if so, Toward What?
# - Topics: scientometrics and bibliometrics research, Scientific Computing and Data Management, Research Data Management Practices
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Incitations explicites et implicites dans les universités en concurrence
# - Topics: scientometrics and bibliometrics research, Private Equity and Venture Capital, Economic Theory and Institutions
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.11
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Science joins Nature in opening reference citations
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Health and Medical Research Impacts
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Some thoughts on transparency of the data and analysis behind the Highly Cited Researchers list
# - Topics: scientometrics and bibliometrics research, Meta-analysis and systematic reviews, Academic Writing and Publishing
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.11
#
# User Info: User Profile:
#  Interested in: Doctoral Education Challenges and Solutions, Meta-analysis and systematic reviews. Prefers novelty: 0.34, reputability bias: 0.47
# Paper Info: Paper Details:
# - Title: Productivity in academia
# - Topics: scientometrics and bibliometrics research, Higher Education Governance and Development
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.20
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Citation opportunity cost of the high impact factor obsession
# - Topics: scientometrics and bibliometrics research, Meta-analysis and systematic reviews, Academic Publishing and Open Access
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.21
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Daily Briefing: How open access mandates measure up
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Professions: Mechanical Solidarity and Process or: "How I learnt to live with a primitive society"
# - Topics: scientometrics and bibliometrics research, Management and Organizational Studies, Doctoral Education Challenges and Solutions
# - Normalized Year (0-1): 0.95
# - Normalized Citations (Reputability) (0-1): 0.20
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Issue Publication Information
# - Topics: scientometrics and bibliometrics research, Academic Writing and Publishing
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Journal ranking by different parameter. Part I. Collectivity and selective collectivity: Two ranking parameters reflecting the structure of a journal network
# - Topics: scientometrics and bibliometrics research, Web visibility and informetrics, Complex Network Analysis Techniques
# - Normalized Year (0-1): 0.97
# - Normalized Citations (Reputability) (0-1): 0.19
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Towards an Epistemic Approach to Evaluation in SSH
# - Topics: scientometrics and bibliometrics research, Contemporary Sociological Theory and Practice, Data Analysis and Archiving
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.33
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Windy Ridge wins first place in the Science Olympiad - Central Region
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Interdisciplinary Research and Collaboration
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Issue Publication Information
# - Topics: scientometrics and bibliometrics research, History and advancements in chemistry
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: How to Do a Review of the Literature?
# - Topics: scientometrics and bibliometrics research, Academic Writing and Publishing, Biomedical Text Mining and Ontologies
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.09
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: A National Research Council-Style Study
# - Topics: scientometrics and bibliometrics research, Data Analysis and Archiving, Spatial and Panel Data Analysis
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.33
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Spotlights on our sister journals: Chem. Eur. J. 5/2010
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: VARIAN associates
# - Topics: scientometrics and bibliometrics research, Inorganic and Organometallic Chemistry
# - Normalized Year (0-1): 0.93
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Real world impact: Towards holistic analysis of author‐level publication metrics
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Academic Writing and Publishing
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Publication trends of neurology articles in a biomedical journal from India
# - Topics: scientometrics and bibliometrics research, Acute Ischemic Stroke Management
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: A method for identifying the most influential articles in an academic discipline
# - Topics: scientometrics and bibliometrics research, Auditing, Earnings Management, Governance
# - Normalized Year (0-1): 0.97
# - Normalized Citations (Reputability) (0-1): 0.35
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Citation differences across research funding and access modalities
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Meta-analysis and systematic reviews
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.26
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Evaluating scientific journals with <i>Journal Citation Reports</i> — a case study in acoustics
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.95
# - Normalized Citations (Reputability) (0-1): 0.38
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Patent citation analysis
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Health and Medical Research Impacts
# - Normalized Year (0-1): 0.97
# - Normalized Citations (Reputability) (0-1): 0.20
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: A need for accuracy during bibliometric assessments
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Health and Medical Research Impacts
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Publishing in Open-access Journals: Is There a Risk?
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: LEEDS NORTHRUP
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.93
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Why Haven't You Published That Research (and Your Other Ideas)?
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.97
# - Normalized Citations (Reputability) (0-1): 0.11
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Research Guides: Sociology: Citation Searching
# - Topics: scientometrics and bibliometrics research, Evaluation and Performance Assessment
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Índice de Osk: una nueva medición bibliométrica para las revistas científicas
# - Topics: scientometrics and bibliometrics research, Business, Innovation, and Economy
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.17
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: LEVER Research-open door to new markets
# - Topics: scientometrics and bibliometrics research, Academic Writing and Publishing
# - Normalized Year (0-1): 0.93
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: LibGuides: Faculty Scholarship Resources: Journal Ranking
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: LibGuides: Citing Sources & Plagiarism/Copyright: Mendeley
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics. Prefers novelty: 0.94, reputability bias: 0.69
# Paper Info: Paper Details:
# - Title: Patterns of Name Ordering Among Authors of Scientific Papers: A Study of Social Symbolism and Its Ambiguity
# - Topics: scientometrics and bibliometrics research, Biomedical Text Mining and Ontologies, Names, Identity, and Discrimination Research
# - Normalized Year (0-1): 0.94
# - Normalized Citations (Reputability) (0-1): 0.60
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics, Psychology Research and Bibliometrics, Conferences and Exhibitions Management. Prefers novelty: 0.67, reputability bias: 0.85
# Paper Info: Paper Details:
# - Title: MRET: Modified Recursive Elimination Technique for ranking author assessment parameters
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics, Psychology Research and Bibliometrics, Conferences and Exhibitions Management. Prefers novelty: 0.67, reputability bias: 0.85
# Paper Info: Paper Details:
# - Title: Are “Sleeping Beauties” to be expected?
# - Topics: scientometrics and bibliometrics research, Complex Systems and Time Series Analysis, Forecasting Techniques and Applications
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.43
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics, Psychology Research and Bibliometrics, Conferences and Exhibitions Management. Prefers novelty: 0.67, reputability bias: 0.85
# Paper Info: Paper Details:
# - Title: A Bibliometric Assessment of the Intellectual Content and Recognition Level of the Journal of the National Science Foundation of Sri Lanka
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics, Psychology Research and Bibliometrics, Conferences and Exhibitions Management. Prefers novelty: 0.67, reputability bias: 0.85
# Paper Info: Paper Details:
# - Title: Institutional efforts: popularization of science in the mid 19th century.
# - Topics: scientometrics and bibliometrics research, Science and Science Education
# - Normalized Year (0-1): 0.96
# - Normalized Citations (Reputability) (0-1): 0.14
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics, Psychology Research and Bibliometrics, Conferences and Exhibitions Management. Prefers novelty: 0.67, reputability bias: 0.85
# Paper Info: Paper Details:
# - Title: Peer review: What is it good for?
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Academic Writing and Publishing
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Web visibility and informetrics, Psychology Research and Bibliometrics, Conferences and Exhibitions Management. Prefers novelty: 0.67, reputability bias: 0.85
# Paper Info: Paper Details:
# - Title: Publishing in January and Impact on Citations: Does the Data Support the Strategy?
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 1        |
# |    exploration_rate | 0.92     |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 12       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 84       |
# ----------------------------------
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Public Research Funding and Scientific Productivity
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Authorship in journal articles: A concern
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Pharmaceutical industry and healthcare
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Thirty Meter Telescope (TMT) Research as Reflected in Web of Science: A Study
# - Topics: scientometrics and bibliometrics research, Big Data and Business Intelligence
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Measuring research quality in a more inclusive way: Evidence from the UK Research Excellence Framework
# - Topics: scientometrics and bibliometrics research, Innovation Policy and R&D, Diversity and Career in Medicine
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Library Guides: Grants Resources: Proposal Writing and Info
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Open Access
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.15
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: As We See It
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.92
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Advertisement
# - Topics: scientometrics and bibliometrics research, Chemistry and Chemical Engineering, Academic Writing and Publishing
# - Normalized Year (0-1): 0.93
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Cooperation and competition in the sciences
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: A slight glance at peer review
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Academic Writing and Publishing
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Diferencias y evolución del impacto académico en los perfiles de Google Scholar Citations: Una aplicación de árboles de decisión
# - Topics: scientometrics and bibliometrics research, Knowledge Management in Higher Education, Psychology Research and Bibliometrics
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.20
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: The Ontology of the Scholarly Journal and the Place of Peer Review
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.09
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Hewlett Packard investing in academia
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: And now for something completely different: the congruence of the Altmetric Attention Score’s structure between different article groups
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.32
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Theoretical difference between impact factor and influence factor
# - Topics: scientometrics and bibliometrics research, Web visibility and informetrics
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Publishing behavior of individuals and most prolific authors in the economics literature
# - Topics: scientometrics and bibliometrics research, Auditing, Earnings Management, Governance, Economic Theory and Institutions
# - Normalized Year (0-1): 0.97
# - Normalized Citations (Reputability) (0-1): 0.30
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: How to get published in Nature
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Is multidisciplinary research more highly cited? A macrolevel study
# - Topics: scientometrics and bibliometrics research, Research Data Management Practices, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.53
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Letter from [Ann G. Muir] to Emma [Muir], 1888 Apr 19.
# - Topics: scientometrics and bibliometrics research, Genetics, Bioinformatics, and Biomedical Research
# - Normalized Year (0-1): 0.81
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Analysis on the use of first personal pronouns in English abstracts of medical research articles
# - Topics: scientometrics and bibliometrics research, Biomedical Text Mining and Ontologies
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.05
#
# User Info: User Profile:
#  Interested in: Academic Writing and Publishing, Academic Publishing and Open Access. Prefers novelty: 0.33, reputability bias: 0.4
# Paper Info: Paper Details:
# - Title: Harvesting footnotes in a rural field: citation patterns in Swedish literary studies
# - Topics: scientometrics and bibliometrics research, Publishing and Scholarly Communication
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.31
#
# User Info: User Profile:
#  Interested in: Philosophy and History of Science, scientometrics and bibliometrics research, Chemistry and Chemical Engineering. Prefers novelty: 0.56, reputability bias: 0.7
# Paper Info: Paper Details:
# - Title: Open science cannot succeed without open peer review
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access, Science and Climate Studies
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.09
#
# User Info: User Profile:
#  Interested in: Philosophy and History of Science, scientometrics and bibliometrics research, Chemistry and Chemical Engineering. Prefers novelty: 0.56, reputability bias: 0.7
# Paper Info: Paper Details:
# - Title: Passing Review: how the R-index aims to improve the peer-review system by quantifying reviewer contributions.
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Philosophy and History of Science, scientometrics and bibliometrics research, Chemistry and Chemical Engineering. Prefers novelty: 0.56, reputability bias: 0.7
# Paper Info: Paper Details:
# - Title: Announcing AMS Protocols
# ...
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Library Guides: NIH Public Access Policy: for Researchers and Authors: Citing PMCIDs
# - Topics: scientometrics and bibliometrics research, Academic Publishing and Open Access
# - Normalized Year (0-1): 0.99
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Conferences and Exhibitions Management, Intellectual Capital and Performance Analysis. Prefers novelty: 0.39, reputability bias: 0.53
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Innovation and Knowledge Management, Academic Writing and Publishing, Scientific Computing and Data Management. Prefers novelty: 0.86, reputability bias: 0.59
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Innovation and Knowledge Management, Academic Writing and Publishing, Scientific Computing and Data Management. Prefers novelty: 0.86, reputability bias: 0.59
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Innovation and Knowledge Management, Academic Writing and Publishing, Scientific Computing and Data Management. Prefers novelty: 0.86, reputability bias: 0.59
# Paper Info: Paper Details:
# - Title: Issue Publication Information
# - Topics: scientometrics and bibliometrics research
# - Normalized Year (0-1): 1.00
# - Normalized Citations (Reputability) (0-1): 0.00
#
# User Info: User Profile:
#  Interested in: Innovation and Knowledge Management, Academic Writing and Publishing, Scientific Computing and Data Management. Prefers novelty: 0.86, reputability bias: 0.59
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Innovation and Knowledge Management, Academic Writing and Publishing, Scientific Computing and Data Management. Prefers novelty: 0.86, reputability bias: 0.59
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Innovation and Knowledge Management, Academic Writing and Publishing, Scientific Computing and Data Management. Prefers novelty: 0.86, reputability bias: 0.59
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Innovation and Knowledge Management, Academic Writing and Publishing, Scientific Computing and Data Management. Prefers novelty: 0.86, reputability bias: 0.59
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Innovation and Knowledge Management, Academic Writing and Publishing, Scientific Computing and Data Management. Prefers novelty: 0.86, reputability bias: 0.59
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Innovation and Knowledge Management, Academic Writing and Publishing, Scientific Computing and Data Management. Prefers novelty: 0.86, reputability bias: 0.59
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54
#
# User Info: User Profile:
#  Interested in: Innovation and Knowledge Management, Academic Writing and Publishing, Scientific Computing and Data Management. Prefers novelty: 0.86, reputability bias: 0.59
# Paper Info: Paper Details:
# - Title: Is commercialization good or bad for science? Individual-level evidence from the Max Planck Society
# - Topics: scientometrics and bibliometrics research, Innovation and Knowledge Management, Innovation Policy and R&D
# - Normalized Year (0-1): 0.98
# - Normalized Citations (Reputability) (0-1): 0.54

# %%
len(rewards)
# Out:
# 253

# %%
import torch
def plot_rewards(episode_rewards, window_size=100):
    rewards_t = torch.tensor(episode_rewards, dtype=torch.float)
    plt.xlabel('Episode')
    plt.ylabel('Reward')
    if len(rewards_t) >= window_size:
        means = rewards_t.unfold(0, window_size, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(window_size-1), means))
        print(len(means))
        plt.plot(means.numpy())

plot_rewards(rewards)
# Out:
# 253

# %%
model.save("models/dqn_citation_recommender_llm")

# %%
# ===============================
# Top-K Citation Recommendations for a User
# ===============================


# Reset environment to get a new user
obs = env.reset()[0]

# Simulate top-K
K = 5
recommended_items = []

for _ in range(K):
    action, _ = model.predict(obs, deterministic=True)
    item_id = env.unwrapped.action_to_item[int(action)]
    citation = env.unwrapped.items_loader.load_items_from_ids([item_id])[0]
    recommended_items.append(citation)
    obs, reward, done, truncated, info = env.step(action)

# Display user info
user_info = env.unwrapped._user
print(f"\n👤 User: {user_info.name}")
print(f"   Description: {user_info.description}")

# Display recommended papers
print("\n📚 Top-K Recommended Papers:")
for idx, citation in enumerate(recommended_items):
    print(f"\n[{idx+1}] Title: {citation.title}")
    print(f"    Year: {citation.year}")
    print(f"    Topics: {citation.topics}")
    print(f"    Citations: {citation.cited_by_count}")
    print(f"    Norm Year: {citation.norm_year:.2f} | Norm Citations: {citation.norm_cite:.2f}")
